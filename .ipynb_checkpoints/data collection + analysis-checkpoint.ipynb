# %%
import csv
import os
import pandas as pd
from datetime import datetime, timedelta
import chardet

news_companies = {
    "Inquirer.net": "https://www.inquirer.net/",
    "Manila Bulletin": "https://mb.com.ph/",
    "The Asian Journal USA": "https://asianjournal.com/",
    "The Manila Times": "https://www.manilatimes.net/",
    "Business World": "https://www.bworldonline.com/",
    "Eagle News": "https://www.eaglenews.ph/",
    "Metro Cebu News": "https://metrocebu.news/",
    "Tempo": "https://tempo.com.ph/",
    "Abante Tonite": "https://tonite.abante.com.ph/",
    "Philippine News Agency": "https://www.pna.gov.ph/",
    "InterAksyon": "https://interaksyon.philstar.com/",
    "Business Mirror": "https://businessmirror.com.ph/",
    "The Summit Express": "https://www.thesummitexpress.com/",
    "Our Daily News Online": "https://ourdailynewsonline.com/",
    "Current PH": "https://currentph.com/",
    "SunStar Philippines": "https://www.sunstar.com.ph/",
    "Rappler": "https://www.rappler.com/",
    "The Bohol Chronicle": "https://www.boholchronicle.com.ph/",
    "Baguio Midland Courier": "https://www.baguiomidlandcourier.com.ph/",
    "GMA News Online": "https://www.gmanetwork.com/news/",
    "Cebu Daily News": "https://cebudailynews.inquirer.net/",
    "ABS-CBN News": "https://news.abs-cbn.com/",
    "Philstar.com": "https://www.philstar.com/",
    "Manila Standard": "https://manilastandard.net/",
    "Daily Tribune": "https://tribune.net.ph/",
    "Davao Today": "https://davaotoday.com/",
    "Sunday Punch": "https://punch.dagupan.com/",
    "Visayan Daily Star": "https://visayandailystar.com/",
    "PTV News": "https://ptvnews.ph/",
    "Mindanao Times": "https://mindanaotimes.com.ph/",
    "PhilNews.XYZ": "https://philnews.xyz/",
    "Northern Dispatch": "https://nordis.net/"
}

news_topics = [
    "inflation",
    "economy",
    "business",
    "technology",
    "health",
    "environment",
    "welfare",
    "politics",
    "foreign_affairs"
]

raw_folder = {
  'business' : ['Business1.csv', 'Business2.csv', 'Business3.csv', 'Business5.csv', 'Business6.csv', 'Business7.csv', 'Business8.csv', ],
  'economy' : ['Economy1.csv','Economy2.csv'],
  'environment' : ['Environment1.csv','Environment2.csv','Environment3.csv','Environment4.csv',],
  'foreign_affairs' : ['ForeignAffairs1.csv'],
  'health': ['Health1.csv','Health2.csv','Health3.csv','Health4.csv',],
  'inflation':['Inflation1.csv'],
  'politics':['Politics1.csv','Politics2.csv'],
  'technology':['Technology1.csv','Technology2.csv','Technology3.csv','Technology4.csv','Technology5.csv',],
  'welfare':['Welfare1.csv']
}

filtered_folder = {
  'business':'business_tally.csv',
  'economy':'economy_tally.csv',
  'environment' :'environment_tally.csv',
  'foreign_affairs' :'foreign_affairs_tally.csv',
  'health':'health_tally.csv',
  'inflation':'inflation_tally.csv',
  'politics':'politics_tally.csv',
  'technology':'technology_tally.csv',
  'welfare':'welfare_tally.csv'
}

# %%
# Creates an empty dataset with columns month, day and all the news sources
def empty_dataset(topic):
    # Define the header columns
    header_columns = ["Month", "Day"] + list(news_companies.keys())

    # Specify the folder and filename
    folder_name = "filtered_datasets"
    filename = os.path.join(folder_name, topic + "_tally.csv")

    # Ensure the folder exists
    os.makedirs(folder_name, exist_ok=True)

    # Generate the date range from January 1 to April 30
    start_date = datetime(2024, 1, 1)
    end_date = datetime(2024, 4, 30)
    date_range = [start_date + timedelta(days=x) for x in range((end_date - start_date).days + 1)]

    # Prepare the rows with preset values
    rows = []
    for date in date_range:
        month = date.strftime("%B")  # Full month name
        day = date.day
        row = [month, day] + [0] * len(news_companies)
        rows.append(row)

    # Open the file in write mode
    with open(filename, 'w', newline='') as csvfile:
        # Create a csv writer object
        csvwriter = csv.writer(csvfile)

        # Write the header row
        csvwriter.writerow(header_columns)

        # Write the rows with preset values
        csvwriter.writerows(rows)
    print(f"Finished creating '{topic}' dataset as '{topic}_tally.csv'.")

# Creates a dataset per topic included in news_topics
def create_empty_datasets():
    for topic in news_topics:
        print(f"Creating final dataset for {topic}.")
        empty_dataset(topic)

# %%
# Function that increments the cell specified by the dataset, month, day and source
def record(filename, month, day, header):
    df = pd.read_csv(filename)
    # Find the row that matches the month and day
    row_index = df[(df['Month'] == month) & (df['Day'] == day)].index

    if not row_index.empty:
        # Increment the value in the specified column
        df.at[row_index[0], header] += 1
    else:
        print(f"No matching row found for {month} {day}")

    df.to_csv(filename, index=False)

    print(f"'{filename}''{day}''{month}''{header}' recorded")

# Sample call
# record("health_tally.csv","January", 1, "Inquirer.net")

# %%
def is_url_from_list(url):
    # Ensure url is a string to avoid TypeError
    if not isinstance(url, str):
        return False
    for key, value in news_companies.items():
        if value in url:
            return key
    return False

# Sample calls
url = "https://www.inquiresr.net/some-article/d"
result = is_url_from_list(url)
print(result)  # Output: Inquirer.net


url = "https://www.inquirer.net/some-article/d"
result = is_url_from_list(url)
print(result)  # Output: Flase
# Out:
# False
# Inquirer.net

# %%
# Function to parse the date and extract month and day
def parse_date(row):
    if isinstance(row, str):  # Check if the input is a string
        try:
            date_str = row.split('\t')[0]
            date_time_str = date_str.strip()
            date_obj = datetime.strptime(date_time_str, '%d-%b-%Y %I:%M%p')
            return date_obj
        except ValueError:
            return None  # Return None for invalid dates
    else:
        return None  # Return None for non-string inputs

# Function to filter each row in each dataset provided the filename of the raw dataset, and the filename of the topic dataset
def raw_data_processing(filename, topicDataset):
    print(f"Filtering raw dataset: '{filename}'.")
    # Dictionary to map month numbers to month names
    month_dict = {
        1: "January", 2: "February", 3: "March", 4: "April",
        5: "May", 6: "June", 7: "July", 8: "August",
        9: "September", 10: "October", 11: "November", 12: "December"
    }

    input_filename = os.path.join("raw_datasets", filename)
    output_filename = os.path.join("filtered_datasets", topicDataset)

    # Detect the encoding of the CSV file
    with open(input_filename, 'rb') as f:
        result = chardet.detect(f.read())
        encoding = result['encoding']

    # Read the CSV file with error handling and correct delimiter
    df = pd.read_csv(input_filename, encoding=encoding, sep='\t', on_bad_lines='skip')

    # Iterate through each row in the DataFrame
    for index, row in df.iterrows():
        date_str = row['Date']
        url = row['URL']

        # Parse the date to get month and day
        date_obj = parse_date(date_str)
        if date_obj:
            month = month_dict[date_obj.month]
            day = date_obj.day
            # Print or store the values as needed
            header = is_url_from_list(url)
            if header != False:
                record(output_filename, month, day, header)
        else:
            print(f"Invalid date format in row {index}")
    print(f"Finished filtering raw dataset: '{filename}'.")

# %%
# Main code block for execution
create_empty_datasets()
# Out:
# Creating final dataset for inflation.
# Finished creating 'inflation' dataset as 'inflation_tally.csv'.
# Creating final dataset for economy.
# Finished creating 'economy' dataset as 'economy_tally.csv'.
# Creating final dataset for business.
# Finished creating 'business' dataset as 'business_tally.csv'.
# Creating final dataset for technology.
# Finished creating 'technology' dataset as 'technology_tally.csv'.
# Creating final dataset for health.
# Finished creating 'health' dataset as 'health_tally.csv'.
# Creating final dataset for environment.
# Finished creating 'environment' dataset as 'environment_tally.csv'.
# Creating final dataset for welfare.
# Finished creating 'welfare' dataset as 'welfare_tally.csv'.
# Creating final dataset for politics.
# Finished creating 'politics' dataset as 'politics_tally.csv'.
# Creating final dataset for foreign_affairs.
# Finished creating 'foreign_affairs' dataset as 'foreign_affairs_tally.csv'.

# %%
def collect_data():
  # Loop through each topic
  for topic in news_topics:
      # Loop through each file in the current topic's folder
      for filename in raw_folder[topic]:
          # Construct the output filename using the filtered_folder dictionary
          output_filename = filtered_folder[topic]
          # Call the processing function with the constructed filenames
          raw_data_processing(filename, output_filename)
  print(f"Data collection completed.")

collect_data()
# Out:
# Filtering raw dataset: 'Inflation1.csv'.
# 'filtered_datasets\inflation_tally.csv''30''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Metro Cebu News' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Cebu Daily News' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''InterAksyon' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''30''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Cebu Daily News' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Rappler' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''29''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''28''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''28''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''28''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''28''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''28''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''28''April''SunStar Philippines' recorded
# 'filtered_datasets\inflation_tally.csv''28''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''28''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''28''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''28''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''28''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''28''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''28''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''28''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''28''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''27''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Rappler' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Rappler' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''26''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Rappler' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Cebu Daily News' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Current PH' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Metro Cebu News' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''25''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Metro Cebu News' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''SunStar Philippines' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Cebu Daily News' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''24''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Rappler' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''SunStar Philippines' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''23''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''SunStar Philippines' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Rappler' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''22''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''Rappler' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''SunStar Philippines' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''InterAksyon' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''21''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''20''April''SunStar Philippines' recorded
# 'filtered_datasets\inflation_tally.csv''20''April''Rappler' recorded
# 'filtered_datasets\inflation_tally.csv''20''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''20''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''20''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''20''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''20''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''20''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''20''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''20''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''20''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''20''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''20''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''20''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''SunStar Philippines' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''SunStar Philippines' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''InterAksyon' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''InterAksyon' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Rappler' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Visayan Daily Star' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Visayan Daily Star' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''19''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''SunStar Philippines' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''SunStar Philippines' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''InterAksyon' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Metro Cebu News' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''SunStar Philippines' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Cebu Daily News' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''SunStar Philippines' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Visayan Daily Star' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''18''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''SunStar Philippines' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Cebu Daily News' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''ABS-CBN News' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''SunStar Philippines' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''InterAksyon' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Visayan Daily Star' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Daily Tribune' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''17''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''GMA News Online' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''Business Mirror' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''Business World' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''Manila Standard' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''SunStar Philippines' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''Philstar.com' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''The Manila Times' recorded
# 'filtered_datasets\inflation_tally.csv''16''April''Philstar.com' recorded
# ...
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Visayan Daily Star' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Visayan Daily Star' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Manila Standard' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Manila Standard' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Business World' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Daily Tribune' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Daily Tribune' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Business Mirror' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Business Mirror' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Business Mirror' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Business Mirror' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Manila Standard' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Business Mirror' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Business Mirror' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Business Mirror' recorded
# 'filtered_datasets\economy_tally.csv''6''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Business Mirror' recorded
# 'filtered_datasets\economy_tally.csv''6''March''Business Mirror' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Philstar.com' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Philstar.com' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Philstar.com' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Philstar.com' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Philstar.com' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Philstar.com' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Philstar.com' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Philstar.com' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Philstar.com' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Philstar.com' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Business World' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Daily Tribune' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Daily Tribune' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Manila Standard' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Business Mirror' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Business World' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Manila Standard' recorded
# 'filtered_datasets\economy_tally.csv''5''March''SunStar Philippines' recorded
# 'filtered_datasets\economy_tally.csv''5''March''SunStar Philippines' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Business Mirror' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Daily Tribune' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Manila Standard' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Rappler' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Cebu Daily News' recorded
# 'filtered_datasets\economy_tally.csv''5''March''ABS-CBN News' recorded
# 'filtered_datasets\economy_tally.csv''5''March''GMA News Online' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''ABS-CBN News' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Daily Tribune' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Manila Standard' recorded
# 'filtered_datasets\economy_tally.csv''5''March''SunStar Philippines' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Daily Tribune' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Rappler' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Business World' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Cebu Daily News' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Manila Standard' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Business Mirror' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Philstar.com' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Daily Tribune' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Daily Tribune' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Manila Standard' recorded
# 'filtered_datasets\economy_tally.csv''5''March''Daily Tribune' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# 'filtered_datasets\economy_tally.csv''5''March''The Manila Times' recorded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 12
#       9           raw_data_processing(filename, output_filename)
#      10   print(f"Data collection completed.")
# ---> 12 collect_data()
#
# Cell In[18], line 9, in collect_data()
#       7         output_filename = filtered_folder[topic]
#       8         # Call the processing function with the constructed filenames
# ----> 9         raw_data_processing(filename, output_filename)
#      10 print(f"Data collection completed.")
#
# Cell In[16], line 48, in raw_data_processing(filename, topicDataset)
#      46     header = is_url_from_list(url)
#      47     if header != False:
# ---> 48         record(output_filename, month, day, header)
#      49 else:
#      50     print(f"Invalid date format in row {index}")
#
# Cell In[14], line 3, in record(filename, month, day, header)
#       2 def record(filename, month, day, header):
# ----> 3     df = pd.read_csv(filename)
#       4     # Find the row that matches the month and day
#       5     row_index = df[(df['Month'] == month) & (df['Day'] == day)].index
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# File <frozen codecs>:309, in __init__(self, errors)
#
# KeyboardInterrupt:

# %%
import pandas as pd
import os

# Folder path where the CSV files are stored (change this to your actual folder path)
folder_path = 'filtered_datasets_old'

# Dictionary containing topics and their corresponding CSV file names
filtered_folder = {
    'business': 'business_tally.csv',
    'economy': 'economy_tally.csv',
    'environment': 'environment_tally.csv',
    'foreign_affairs': 'foreign_affairs_tally.csv',
    'health': 'health_tally.csv',
    'inflation': 'inflation_tally.csv',
    'politics': 'politics_tally.csv',
    'technology': 'technology_tally.csv',
    'welfare': 'welfare_tally.csv'
}

# Initialize an empty dictionary to store the total articles per topic
total_articles_per_topic = {}

# Loop through each topic and corresponding CSV file
for topic, filename in filtered_folder.items():
    # Read the CSV file
    file_path = os.path.join(folder_path, filename)
    df = pd.read_csv(file_path)

    # Drop the 'Month' and 'Day' columns as they are not needed for summing
    df = df.drop(columns=['Month', 'Day'])
    
    # Sum all article counts across all columns (news sources)
    total_articles = df.sum().sum()
    
    # Store the result in the dictionary
    total_articles_per_topic[topic] = total_articles

# Output the total articles per topic
for topic, total in total_articles_per_topic.items():
    print(f"Total articles for {topic}: {total}")
# Out:
# Total articles for business: 32505
# Total articles for economy: 11618
# Total articles for environment: 14683
# Total articles for foreign_affairs: 2057
# Total articles for health: 14686
# Total articles for inflation: 5734
# Total articles for politics: 11616
# Total articles for technology: 20286
# Total articles for welfare: 5081

# %%
# Initialize an empty dictionary to store total articles per news source
total_articles_per_source = {}

# Loop through each topic and corresponding CSV file
for topic, filename in filtered_folder.items():
    # Read the CSV file
    file_path = os.path.join(folder_path, filename)
    df = pd.read_csv(file_path)
    
    # Drop the 'Month' and 'Day' columns
    df = df.drop(columns=['Month', 'Day'])
    
    # Sum articles for each news source (sum along the rows for each column)
    for source in df.columns:
        if source not in total_articles_per_source:
            total_articles_per_source[source] = 0
        total_articles_per_source[source] += df[source].sum()

# Convert the dictionary to a DataFrame for a table format
df_table = pd.DataFrame(list(total_articles_per_source.items()), columns=['News Source', 'Total Articles'])

# Sort the table by total articles (descending order)
df_table = df_table.sort_values(by='Total Articles', ascending=False)

# Display the table
print(df_table)
# Out:
# Total articles for Inquirer.net: 0
# Total articles for Manila Bulletin: 2186
# Total articles for The Asian Journal USA: 0
# Total articles for The Manila Times: 64198
# Total articles for Business World: 5446
# Total articles for Eagle News: 0
# Total articles for Metro Cebu News: 237
# Total articles for Tempo: 22
# Total articles for Abante Tonite: 0
# Total articles for Philippine News Agency: 0
# Total articles for InterAksyon: 473
# Total articles for Business Mirror: 7039
# Total articles for The Summit Express: 80
# Total articles for Our Daily News Online: 0
# Total articles for Current PH: 65
# Total articles for SunStar Philippines: 4498
# Total articles for Rappler: 2236
# Total articles for The Bohol Chronicle: 60
# Total articles for Baguio Midland Courier: 0
# Total articles for GMA News Online: 2762
# Total articles for Cebu Daily News: 933
# Total articles for ABS-CBN News: 2781
# Total articles for Philstar.com: 9580
# Total articles for Manila Standard: 6497
# Total articles for Daily Tribune: 7636
# Total articles for Davao Today: 475
# Total articles for Sunday Punch: 99
# Total articles for Visayan Daily Star: 538
# Total articles for PTV News: 405
# Total articles for Mindanao Times: 0
# Total articles for PhilNews.XYZ: 0
# Total articles for Northern Dispatch: 20
